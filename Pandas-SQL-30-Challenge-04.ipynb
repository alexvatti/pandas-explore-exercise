# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
data = {
    "ID": [1, 2, 3, 4, 5],
    "NAME": [np.nan, "David", np.nan, np.nan, "David"],
    "LOCATION": [np.nan, np.nan, "London", np.nan, np.nan]
}



data
# Out:
# {'ID': [1, 2, 3, 4, 5],
#  'NAME': [nan, 'David', nan, nan, 'David'],
#  'LOCATION': [nan, nan, 'London', nan, nan]}

# %%
df = pd.DataFrame(data)
df
# Out:
#    ID   NAME LOCATION
# 0   1    NaN      NaN
# 1   2  David      NaN
# 2   3    NaN   London
# 3   4    NaN      NaN
# 4   5  David      NaN

# %%
df.fillna(method='bfill').head(1)
# Out:
# C:\Users\91956\AppData\Local\Temp\ipykernel_17412\3358591809.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill').head(1)
#    ID   NAME LOCATION
# 0   1  David   London

# %%
df
# Out:
#    ID   NAME LOCATION
# 0   1    NaN      NaN
# 1   2  David      NaN
# 2   3    NaN   London
# 3   4    NaN      NaN
# 4   5  David      NaN

# %%
df.fillna(method='ffill').tail(1)
# Out:
# C:\Users\91956\AppData\Local\Temp\ipykernel_17412\573884160.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill').tail(1)
#    ID   NAME LOCATION
# 4   5  David   London
