# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np

# Define the job_skills data
data = [
    (1, 'Data Engineer', 'SQL'),
    (2, None, 'Python'),
    (3, None, 'AWS'),
    (4, None, 'Snowflake'),
    (5, None, 'Apache Spark'),
    (6, 'Web Developer', 'Java'),
    (7, None, 'HTML'),
    (8, None, 'CSS'),
    (9, 'Data Scientist', 'Python'),
    (10, None, 'Machine Learning'),
    (11, None, 'Deep Learning'),
    (12, None, 'Tableau')
]

# Create a DataFrame
df = pd.DataFrame(data, columns=['ROW_ID', 'JOB_ROLE', 'SKILLS'])
df
# Out:
#     ROW_ID        JOB_ROLE            SKILLS
# 0        1   Data Engineer               SQL
# 1        2            None            Python
# 2        3            None               AWS
# 3        4            None         Snowflake
# 4        5            None      Apache Spark
# 5        6   Web Developer              Java
# 6        7            None              HTML
# 7        8            None               CSS
# 8        9  Data Scientist            Python
# 9       10            None  Machine Learning
# 10      11            None     Deep Learning
# 11      12            None           Tableau

# %%
df["JOB_ROLE"]=df["JOB_ROLE"].ffill()
df
# Out:
#     ROW_ID        JOB_ROLE            SKILLS
# 0        1   Data Engineer               SQL
# 1        2   Data Engineer            Python
# 2        3   Data Engineer               AWS
# 3        4   Data Engineer         Snowflake
# 4        5   Data Engineer      Apache Spark
# 5        6   Web Developer              Java
# 6        7   Web Developer              HTML
# 7        8   Web Developer               CSS
# 8        9  Data Scientist            Python
# 9       10  Data Scientist  Machine Learning
# 10      11  Data Scientist     Deep Learning
# 11      12  Data Scientist           Tableau
